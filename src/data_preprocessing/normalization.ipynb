# %%
import sys
import os
from normalize_fn import load

# %%
X_tr_np, X_val_np, X_train_np, X_test_np, y_tr_np, y_val_np, y_train_np, y_test_np = load_and_normalize(norm='tanh_norm')

# %%
print("X_tr_np:", X_tr_np.shape)
print("y_tr_np:", y_tr_np.shape)
print("X_val_np:", X_val_np.shape)
print("y_val_np:", y_val_np.shape)
